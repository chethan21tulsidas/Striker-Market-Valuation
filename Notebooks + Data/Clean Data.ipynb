# %%
import pandas as pd
import numpy as np

pd.options.display.max_columns = None

# %%
player_data = pd.read_csv("players_22.csv", low_memory=False)

player_data.head(10)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 5     200389  https://sofifa.com/player/200389/jan-oblak/220002
# 6     231747  https://sofifa.com/player/231747/kylian-mbappe...
# 7     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 8     192448  https://sofifa.com/player/192448/marc-andre-te...
# 9     202126  https://sofifa.com/player/202126/harry-kane/22...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# ...

# %%
player_data[player_data['player_positions'].str.contains('ST')]
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1         188545  https://sofifa.com/player/188545/robert-lewand...
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 6         231747  https://sofifa.com/player/231747/kylian-mbappe...
# 9         202126  https://sofifa.com/player/202126/harry-kane/22...
# ...          ...                                                ...
# 19201     261666  https://sofifa.com/player/261666/callum-warfie...
# 19203     261876  https://sofifa.com/player/261876/conan-noonan/...
# 19219     264150  https://sofifa.com/player/264150/ebuka-kwelele...
# 19220     243725  https://sofifa.com/player/243725/darren-collin...
# 19237     262820  https://sofifa.com/player/262820/luke-rudden/2...
#
#               short_name                            long_name  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini
# ...

# %%
striker_data = player_data[player_data['player_positions'].str.contains('ST')]

striker_data.sample(10)
# Out:
#        sofifa_id                                         player_url  \
# 13444     199014  https://sofifa.com/player/199014/david-mcmilla...
# 18827     263212  https://sofifa.com/player/263212/tom-costello/...
# 10128     217098  https://sofifa.com/player/217098/jose-miguel-r...
# 18454     244465  https://sofifa.com/player/244465/jack-hamilton...
# 7100      237380  https://sofifa.com/player/237380/hamidou-keyta...
# 7441      260592  https://sofifa.com/player/260592/benjamin-sesk...
# 18662     236452  https://sofifa.com/player/236452/daniel-lalhli...
# 17337     262005  https://sofifa.com/player/262005/dejan-galjen/...
# 4200      222262  https://sofifa.com/player/222262/cyriel-desser...
# 9167      229745  https://sofifa.com/player/229745/bright-enobak...
#
#            short_name                long_name player_positions  overall  \
# 13444     D. McMillan           David McMillan               ST       62
# ...

# %%
#cols = ['short_name', 'player_positions', 'overall', 'potential', 'value_eur', 'age', 'club_contract_valid_until', 'weak_foot', 'international_reputation', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_volleys', 'power_shot_power', 'power_long_shots', 'skill_ball_control', 'mentality_positioning']

# %%
cols = ['short_name', 'player_positions', 'overall', 'potential', 'value_eur', 'age', 'club_contract_valid_until', 'weak_foot', 'international_reputation', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic'] #, 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_volleys', 'power_shot_power', 'power_long_shots', 'skill_ball_control', 'mentality_positioning']

# %%
clean_data = striker_data[cols]

clean_data.head(10)
# Out:
#            short_name player_positions  overall  potential    value_eur  age  \
# 0            L. Messi       RW, ST, CF       93         93   78000000.0   34
# 1      R. Lewandowski               ST       92         92  119500000.0   32
# 2   Cristiano Ronaldo           ST, LW       91         91   45000000.0   36
# 6           K. Mbappé           ST, LW       91         95  194000000.0   22
# 9             H. Kane               ST       90         90  129500000.0   27
# 11         K. Benzema           CF, ST       89         89   66000000.0   33
# 23          L. Suárez               ST       88         88   44500000.0   34
# 25          R. Lukaku               ST       88         88   93500000.0   28
# 29         E. Haaland               ST       88         93  137500000.0   20
# 30          S. Agüero               ST       87         87   51000000.0   33
#
#     club_contract_valid_until  weak_foot  international_reputation  pace  \
# ...

# %%
#clean_data['age_sqr'] = clean_data['age'] ** 2

#clean_data.sample(10)

# %%
clean_data['years_left'] = clean_data['club_contract_valid_until'] - 2021

clean_data.sample(10)
# Out:
# <ipython-input-9-a6302e175eb7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data['years_left'] = clean_data['club_contract_valid_until'] - 2021
#             short_name player_positions  overall  potential   value_eur  age  \
# 16282         A. Foley               ST       59         59    190000.0   31
# 5259       Y. Bárcenas       LM, RM, ST       70         70   1700000.0   27
# 6937       B. Mansilla       LM, LW, ST       68         73   1800000.0   24
# 8675           Gao Lin           LW, ST       66         66    350000.0   35
# 2665        Lucas João               ST       73         73   3300000.0   27
# 500           M. Gómez               ST       80         85  32000000.0   24
# ...

# %%
clean_data['years_left'] = pd.to_numeric(clean_data['years_left'])

clean_data.sample(10)
# Out:
# <ipython-input-10-dff152cc0c49>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data['years_left'] = pd.to_numeric(clean_data['years_left'])
#             short_name player_positions  overall  potential  value_eur  age  \
# 3454       E. Crivelli           ST, LW       72         74  2900000.0   26
# 17246         L. Hakim           ST, CF       57         71   400000.0   19
# 7738      Ł. Zwoliński           ST, RM       67         67  1000000.0   28
# 4354      Felipe Vizeu           ST, CF       71         75  2700000.0   24
# 2143         M. Rangel               ST       74         74  4100000.0   30
# 13768        J. Gordon           RW, ST       62         63   475000.0   26
# ...

# %%
clean_data['club_contract_valid_until'].min()
# Out:
# 2021.0

# %%
clean_data['club_contract_valid_until'].max()
# Out:
# 2028.0

# %%
clean_data.tail(10)
# Out:
#           short_name player_positions  overall  potential  value_eur  age  \
# 19154        Li Boxi               ST       49         56    90000.0   20
# 19167      A. Emakhu               ST       49         72   150000.0   17
# 19177  E. Lalrindika               ST       48         59   110000.0   22
# 19187        P. Kyum               ST       48         53    70000.0   20
# 19195       H. Singh               ST       48         56   100000.0   19
# 19201    C. Warfield               ST       48         57   100000.0   20
# 19203      C. Noonan               ST       48         64   120000.0   18
# 19219     E. Kwelele               ST       48         62   110000.0   19
# 19220     D. Collins           ST, RM       47         56   100000.0   20
# 19237      L. Rudden               ST       47         60   110000.0   19
#
#        club_contract_valid_until  weak_foot  international_reputation  pace  \
# 19154                     2022.0          3                         1  58.0
# ...

# %%
clean_data['value_log10'] = np.log10(clean_data['value_eur'])

clean_data.sample(10)
# Out:
# <ipython-input-14-add4ecb0e861>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data['value_log10'] = np.log10(clean_data['value_eur'])
#               short_name player_positions  overall  potential  value_eur  age  \
# 17185  T. Dickson-Peters               ST       57         70   375000.0   18
# 5802              Willie          ST, CAM       69         69  1400000.0   28
# 1479          M. Boselli               ST       75         75  1900000.0   36
# 11552           G. Hirst               ST       64         74  1300000.0   22
# 13120     P. Steinwender      RM, CAM, ST       63         66   650000.0   24
# 13416      N. Delfouneso          ST, CAM       62         62   400000.0   30
# ...

# %%
#cols = ['short_name', 'player_positions', 'overall', 'potential', 'value_eur', 'value_log10', 'club_contract_valid_until', 'years_left', 'age', 'weak_foot', 'international_reputation', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_volleys', 'power_shot_power', 'power_long_shots', 'skill_ball_control', 'mentality_positioning']

# %%
cols = ['short_name', 'player_positions', 'overall', 'potential', 'value_eur', 'value_log10', 'club_contract_valid_until', 'years_left', 'age', 'weak_foot', 'international_reputation', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic'] #, 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_volleys', 'power_shot_power', 'power_long_shots', 'skill_ball_control', 'mentality_positioning']

# %%
clean_data = clean_data[cols]

clean_data.head(10)
# Out:
#            short_name player_positions  overall  potential    value_eur  \
# 0            L. Messi       RW, ST, CF       93         93   78000000.0
# 1      R. Lewandowski               ST       92         92  119500000.0
# 2   Cristiano Ronaldo           ST, LW       91         91   45000000.0
# 6           K. Mbappé           ST, LW       91         95  194000000.0
# 9             H. Kane               ST       90         90  129500000.0
# 11         K. Benzema           CF, ST       89         89   66000000.0
# 23          L. Suárez               ST       88         88   44500000.0
# 25          R. Lukaku               ST       88         88   93500000.0
# 29         E. Haaland               ST       88         93  137500000.0
# 30          S. Agüero               ST       87         87   51000000.0
#
#     value_log10  club_contract_valid_until  years_left  age  weak_foot  \
# 0      7.892095                     2023.0         2.0   34          4
# ...

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3398 entries, 0 to 19237
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   short_name                 3398 non-null   object
#  1   player_positions           3398 non-null   object
#  2   overall                    3398 non-null   int64
#  3   potential                  3398 non-null   int64
#  4   value_eur                  3385 non-null   float64
#  5   value_log10                3385 non-null   float64
#  6   club_contract_valid_until  3391 non-null   float64
#  7   years_left                 3391 non-null   float64
#  8   age                        3398 non-null   int64
#  9   weak_foot                  3398 non-null   int64
#  10  international_reputation   3398 non-null   int64
#  11  pace                       3398 non-null   float64
#  12  shooting                   3398 non-null   float64
# ...

# %%
clean_data.isnull().sum()
# Out:
# short_name                    0
# player_positions              0
# overall                       0
# potential                     0
# value_eur                    13
# value_log10                  13
# club_contract_valid_until     7
# years_left                    7
# age                           0
# weak_foot                     0
# international_reputation      0
# pace                          0
# shooting                      0
# passing                       0
# dribbling                     0
# defending                     0
# physic                        0
# dtype: int64

# %%
clean_data[clean_data.isnull().any(axis=1)]
# Out:
#          short_name player_positions  overall  potential  value_eur  \
# 694       A. Dzyuba               ST       78         78        NaN
# 1471        J. Sand               ST       75         75        NaN
# 2429   M. Rodríguez       LW, LM, ST       73         73        NaN
# 2499       A. Ionov       RM, LM, ST       73         73        NaN
# 4765     N. Nikolić               ST       70         70        NaN
# 5469   Rubén Castro               ST       69         69        NaN
# 6194      A. Dovbyk               ST       69         75        NaN
# 7496    K. Lafferty               ST       67         67        NaN
# 7744        M. Duke               ST       67         67        NaN
# 11750   C. McCowatt       LW, LM, ST       64         73        NaN
# 16209      K. Miura               ST       59         59        NaN
# 16505    K. Ellison           LM, ST       58         58        NaN
# 17720     C. Dundas               ST       56         56        NaN
#
# ...

# %%
clean_data.dropna()
# Out:
#               short_name player_positions  overall  potential    value_eur  \
# 0               L. Messi       RW, ST, CF       93         93   78000000.0
# 1         R. Lewandowski               ST       92         92  119500000.0
# 2      Cristiano Ronaldo           ST, LW       91         91   45000000.0
# 6              K. Mbappé           ST, LW       91         95  194000000.0
# 9                H. Kane               ST       90         90  129500000.0
# ...                  ...              ...      ...        ...          ...
# 19201        C. Warfield               ST       48         57     100000.0
# 19203          C. Noonan               ST       48         64     120000.0
# 19219         E. Kwelele               ST       48         62     110000.0
# 19220         D. Collins           ST, RM       47         56     100000.0
# 19237          L. Rudden               ST       47         60     110000.0
#
# ...

# %%
final_data = clean_data.dropna()

final_data.sample(10)
# Out:
#           short_name player_positions  overall  potential   value_eur  \
# 15030   R. Berlinski               ST       61         62    400000.0
# 6233           Elady      ST, LM, CAM       69         69   1400000.0
# 15260     Cheng Yuan               ST       60         61    300000.0
# 349          Morales           ST, LM       81         81  16500000.0
# 7792   Kim Seung Dae          ST, CAM       67         67   1000000.0
# 10276   P. Kirkevold               ST       65         65    700000.0
# 8329          C. Abi               ST       67         75   2300000.0
# 8135       A. Zeqiri               ST       67         76   2300000.0
# 14460   F. Al Johani      ST, RM, CAM       61         61    325000.0
# 14067      M. Hosoya               ST       62         72    875000.0
#
#        value_log10  club_contract_valid_until  years_left  age  weak_foot  \
# 15030     5.602060                     2022.0         1.0   26          3
# ...

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3385 entries, 0 to 19237
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   short_name                 3385 non-null   object
#  1   player_positions           3385 non-null   object
#  2   overall                    3385 non-null   int64
#  3   potential                  3385 non-null   int64
#  4   value_eur                  3385 non-null   float64
#  5   value_log10                3385 non-null   float64
#  6   club_contract_valid_until  3385 non-null   float64
#  7   years_left                 3385 non-null   float64
#  8   age                        3385 non-null   int64
#  9   weak_foot                  3385 non-null   int64
#  10  international_reputation   3385 non-null   int64
#  11  pace                       3385 non-null   float64
#  12  shooting                   3385 non-null   float64
# ...

# %%
final_data.isnull().sum()
# Out:
# short_name                   0
# player_positions             0
# overall                      0
# potential                    0
# value_eur                    0
# value_log10                  0
# club_contract_valid_until    0
# years_left                   0
# age                          0
# weak_foot                    0
# international_reputation     0
# pace                         0
# shooting                     0
# passing                      0
# dribbling                    0
# defending                    0
# physic                       0
# dtype: int64

# %%
final_data.to_csv("final_players_22.csv", index=False)
